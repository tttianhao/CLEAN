# %% [markdown]
# ## Demo for maximum separation algorithm, naive implementation

# %%
import numpy as np
import matplotlib.pyplot as plt

dist_lst = np.array([11.0, 11.1, 11.5, 12.22, 12.23,
                    13.4, 13.5, 13.6, 13.6, 13.7])
# approximate the background noise distance with dist_1...dist_9 with
# dist_9 repeated 10 times since the last distance's EC will never be called
gamma = np.append(dist_lst[1:], np.repeat(dist_lst[-1], 10))

sep_lst = np.abs(dist_lst - np.mean(gamma))

sep_grad = []
for i in range(9):
    grad_i = np.abs(sep_lst[i+1] - sep_lst[i])
    sep_grad.append(grad_i)

print(sep_grad > np.mean(sep_grad))

x = range(10)
#plt.plot(x, dist_lst)
plt.plot(x, sep_lst)
# plt.yscale('log')
# Out:
# [False  True  True False  True False False False False]

# %%
## speed up:

dist_lst = np.array([11.0, 11.1, 11.5, 12.22, 12.23, 13.4, 13.5, 13.6, 13.6, 13.7])
dist_lst_prime = np.append(dist_lst[1:], np.repeat(dist_lst[-1], 10))
sep_lst = np.abs(dist_lst - np.mean(dist_lst_prime))
sep_grad = np.abs(sep_lst[:-1]-sep_lst[1:])
large_grads = np.where(sep_grad > np.mean(sep_grad))
max_sep_i = large_grads[-1][-1]
print("large grads:", sep_grad > np.mean(sep_grad))
print("max_sep_i:", max_sep_i)
x = range(10)
#plt.plot(x, dist_lst)
plt.plot(x, sep_lst)
# plt.yscale('log')
# Out:
# large grads: [False  True  True False  True False False False False]
# max_sep_i: 4
